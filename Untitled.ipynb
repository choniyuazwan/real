# %%
df_cluster_1 = pd.read_csv('cluster_1.csv')
df_cluster_4 = pd.read_csv('cluster_4.csv')
df_cluster_5 = pd.read_csv('cluster_5.csv')

# %%
df_cluster_1.head()
# Out:
#    CARDNUM             PROD1             PROD2             PROD3  \
# 0        3     1504:\nCHEESE  2201:\nSAYUR TAN  1003: FRUIT\nJUI
# 1        6  1424:\nCHOCOLATE      1008:\nWATER  1500: FRESH\nMIL
# 2        2    1222: Sanitary  1502: DAIRY\nDES       1414: ROLLS
# 3        5  1440: BABY\nMILK               NaN               NaN
# 4       10  1440: BABY\nMILK               NaN               NaN
#
#               PROD4              PROD5 PROD6 PROD7 PROD8 PROD9  ... PROD51  \
# 0               NaN                NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1  1453:\nINSTANT D  1421:\nSOFT\nCAND   NaN   NaN   NaN   NaN  ...    NaN
# 2               NaN                NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3               NaN                NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4               NaN                NaN   NaN   NaN   NaN   NaN  ...    NaN
#
#   PROD52 PROD53  PROD54  PROD55  PROD56  PROD57  PROD58  PROD59  cluster
# ...

# %%
df_cluster_4.head()
# Out:
#    CARDNUM             PROD1         PROD2             PROD3  PROD4  PROD5  \
# 0        4  1440: BABY\nMILK           NaN               NaN    NaN    NaN
# 1        4  1441: BABY\nFOOD           NaN               NaN    NaN    NaN
# 2        4  1110: Laundry\nd  1220: Tissue  1105:\nDeodorisa    NaN    NaN
# 3        4  2301: TOAST\nBRE           NaN               NaN    NaN    NaN
# 4        4  2001: Main\nDish           NaN               NaN    NaN    NaN
#
#    PROD6  PROD7  PROD8  PROD9  ...  PROD51  PROD52  PROD53  PROD54  PROD55  \
# 0    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    PROD56  PROD57  PROD58  PROD59  cluster
# ...

# %%
df_cluster_5.head()
# Out:
#    CARDNUM             PROD1             PROD2             PROD3 PROD4 PROD5  \
# 0        1  1440: BABY\nMILK               NaN               NaN   NaN   NaN
# 1        1  1440: BABY\nMILK               NaN               NaN   NaN   NaN
# 2        1  1216: Baby\nHygi               NaN               NaN   NaN   NaN
# 3        1  2201: SAYUR\nTAN  1403:\nMODERN SN  1451:\nNOODLES &   NaN   NaN
# 4        1  1001: NON\nCARBO               NaN               NaN   NaN   NaN
#
#   PROD6 PROD7  PROD8  PROD9  ...  PROD51  PROD52  PROD53  PROD54  PROD55  \
# 0   NaN   NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1   NaN   NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2   NaN   NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3   NaN   NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4   NaN   NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    PROD56  PROD57  PROD58  PROD59  cluster
# ...

# %%
print(df_cluster_1.shape)
print(df_cluster_4.shape)
print(df_cluster_5.shape)
# Out:
# (78, 61)
# (9, 61)
# (13, 61)

# %%
df_cluster_1 = df_cluster_1.drop(['CARDNUM', 'cluster'], axis=1)
df_cluster_4 = df_cluster_4.drop(['CARDNUM', 'cluster'], axis=1)
df_cluster_5 = df_cluster_5.drop(['CARDNUM', 'cluster'], axis=1)

# %%
print(df_cluster_1.shape)
print(df_cluster_4.shape)
print(df_cluster_5.shape)
# Out:
# (78, 59)
# (9, 59)
# (13, 59)

# %%
df_cluster_1.head()
# Out:
#               PROD1             PROD2             PROD3             PROD4  \
# 0     1504:\nCHEESE  2201:\nSAYUR TAN  1003: FRUIT\nJUI               NaN
# 1  1424:\nCHOCOLATE      1008:\nWATER  1500: FRESH\nMIL  1453:\nINSTANT D
# 2    1222: Sanitary  1502: DAIRY\nDES       1414: ROLLS               NaN
# 3  1440: BABY\nMILK               NaN               NaN               NaN
# 4  1440: BABY\nMILK               NaN               NaN               NaN
#
#                PROD5 PROD6 PROD7 PROD8 PROD9 PROD10  ... PROD50 PROD51  \
# 0                NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN    NaN
# 1  1421:\nSOFT\nCAND   NaN   NaN   NaN   NaN    NaN  ...    NaN    NaN
# 2                NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN    NaN
# 3                NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN    NaN
# 4                NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN    NaN
#
#    PROD52  PROD53  PROD54  PROD55  PROD56  PROD57  PROD58  PROD59
# ...

# %%
df_cluster_4.head()
# Out:
#               PROD1         PROD2             PROD3  PROD4  PROD5  PROD6  \
# 0  1440: BABY\nMILK           NaN               NaN    NaN    NaN    NaN
# 1  1441: BABY\nFOOD           NaN               NaN    NaN    NaN    NaN
# 2  1110: Laundry\nd  1220: Tissue  1105:\nDeodorisa    NaN    NaN    NaN
# 3  2301: TOAST\nBRE           NaN               NaN    NaN    NaN    NaN
# 4  2001: Main\nDish           NaN               NaN    NaN    NaN    NaN
#
#    PROD7  PROD8  PROD9  PROD10  ...  PROD50  PROD51  PROD52  PROD53  PROD54  \
# 0    NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    PROD55  PROD56  PROD57  PROD58  PROD59
# ...

# %%
df_cluster_5.head()
# Out:
#               PROD1             PROD2             PROD3 PROD4 PROD5 PROD6  \
# 0  1440: BABY\nMILK               NaN               NaN   NaN   NaN   NaN
# 1  1440: BABY\nMILK               NaN               NaN   NaN   NaN   NaN
# 2  1216: Baby\nHygi               NaN               NaN   NaN   NaN   NaN
# 3  2201: SAYUR\nTAN  1403:\nMODERN SN  1451:\nNOODLES &   NaN   NaN   NaN
# 4  1001: NON\nCARBO               NaN               NaN   NaN   NaN   NaN
#
#   PROD7  PROD8  PROD9  PROD10  ...  PROD50  PROD51  PROD52  PROD53  PROD54  \
# 0   NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1   NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2   NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3   NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4   NaN    NaN    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    PROD55  PROD56  PROD57  PROD58  PROD59
# ...

# %%
# convert pandas dataframe to list and then to one hot encoding
# cluster 1
records = []
for i in range(0, df_cluster_1.shape[0]):
    records.append([str(df_cluster_1.values[i,j]) for j in range(0, df_cluster_1.shape[1])])
    
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df_cluster_1_transform = pd.DataFrame(te_ary, columns=te.columns_)
df_cluster_1_transform.drop(['nan'], axis=1, inplace=True)
df_cluster_1_transform
# Out:
#     1001: NON\nCARBO  1003: FRUIT\nJUI  1004: FRUIT\nJUI  1008:\nWATER  \
# 0              False              True             False         False
# 1              False             False             False          True
# 2              False             False             False         False
# 3              False             False             False         False
# 4              False             False             False         False
# 5              False             False             False         False
# 6              False             False             False         False
# 7              False             False             False         False
# 8              False             False             False         False
# 9              False             False             False         False
# 10             False             False             False         False
# 11             False             False             False         False
# ...

# %%
# convert pandas dataframe to list and then to one hot encoding
# cluster 4
records = []
for i in range(0, df_cluster_4.shape[0]):
    records.append([str(df_cluster_4.values[i,j]) for j in range(0, df_cluster_4.shape[1])])
    
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df_cluster_4_transform = pd.DataFrame(te_ary, columns=te.columns_)
df_cluster_4_transform.drop(['nan'], axis=1, inplace=True)
df_cluster_4_transform
# Out:
#    1105:\nDeodorisa  1110: Laundry\nd  1210: SOAP  1220: Tissue  \
# 0             False             False       False         False
# 1             False             False       False         False
# 2              True              True       False          True
# 3             False             False       False         False
# 4             False             False       False         False
# 5             False             False       False         False
# 6             False             False        True         False
# 7             False             False       False         False
# 8             False             False       False         False
#
#    1440: BABY\nMILK  1441: BABY\nFOOD  2001: Main\nDish  2301: TOAST\nBRE  \
# 0              True             False             False             False
# 1             False              True             False             False
# 2             False             False             False             False
# ...

# %%
# convert pandas dataframe to list and then to one hot encoding
# cluster 5
records = []
for i in range(0, df_cluster_5.shape[0]):
    records.append([str(df_cluster_5.values[i,j]) for j in range(0, df_cluster_5.shape[1])])
    
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df_cluster_5_transform = pd.DataFrame(te_ary, columns=te.columns_)
df_cluster_5_transform.drop(['nan'], axis=1, inplace=True)
df_cluster_5_transform
# Out:
#     1001: NON\nCARBO  1105:\nDeodorisa  1216: Baby\nHygi  1403:\nMODERN SN  \
# 0              False             False             False             False
# 1              False             False             False             False
# 2              False             False              True             False
# 3              False             False             False              True
# 4               True             False             False             False
# 5              False             False             False             False
# 6              False             False             False             False
# 7              False             False             False             False
# 8              False             False             False             False
# 9              False             False             False             False
# 10             False             False             False             False
# ...

# %%
# Build up the frequent items# Build  
frequent_itemsets = apriori(df_transform, min_support=0, use_colnames=True)

# %%
frequent_itemsets.shape
# Out:
# (1023, 2)

# %%
frequent_itemsets.head()
# Out:
#     support   itemsets
# 0  0.422111   (Anggur)
# 1  0.396985    (Jeruk)
# 2  0.402010  (alpokat)
# 3  0.437186    (jambu)
# 4  0.412060    (kurma)

# %%
many_bundling = 4
for index, row in frequent_itemsets.iterrows():
    if(len(row['itemsets']) == many_bundling):
        result_bundling = frequent_itemsets.loc[[index]]
        break

result_bundling
# Out:
#       support                         itemsets
# 175  0.015075  (alpokat, jambu, Jeruk, Anggur)

# %%
len(bundling)
# Out:
# 120

# %%
frequent_itemsets.loc[[174]]
# Out:
#       support             itemsets
# 174  0.030151  (pisang, pir, sawo)

# %%
frequent_itemsets.loc[[55]]
# Out:
#      support                  itemsets
# 55  0.045226  (alpokat, Jeruk, Anggur)

# %%
bundling
# Out:
# [55,
#  56,
#  57,
#  58,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174]

# %%
frequent_itemsets.to_csv('frequent_itemsets.csv', index=False)

# %%
frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.422111                                           (Anggur)
# 1     0.396985                                            (Jeruk)
# 2     0.402010                                          (alpokat)
# 3     0.437186                                            (jambu)
# 4     0.412060                                            (kurma)
# 5     0.391960                                           (mangga)
# 6     0.422111                                       (naga merah)
# 7     0.376884                                              (pir)
# 8     0.417085                                           (pisang)
# 9     0.447236                                             (sawo)
# 10    0.130653                                    (Jeruk, Anggur)
# 11    0.150754                                  (alpokat, Anggur)
# 12    0.150754                                    (jambu, Anggur)
# ...

# %%
# Create the rules# Create 
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0)
rules
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 0        (Jeruk)      (Anggur)            0.396985            0.422111
# 1       (Anggur)       (Jeruk)            0.422111            0.396985
# 2      (alpokat)      (Anggur)            0.402010            0.422111
# 3       (Anggur)     (alpokat)            0.422111            0.402010
# 4        (jambu)      (Anggur)            0.437186            0.422111
# 5       (Anggur)       (jambu)            0.422111            0.437186
# 6        (kurma)      (Anggur)            0.412060            0.422111
# 7       (Anggur)       (kurma)            0.422111            0.412060
# 8       (mangga)      (Anggur)            0.391960            0.422111
# 9       (Anggur)      (mangga)            0.422111            0.391960
# 10      (Anggur)  (naga merah)            0.422111            0.422111
# 11  (naga merah)      (Anggur)            0.422111            0.422111
# ...

# %%
rules.shape
# Out:
# (4, 9)

# %%
rules[ (rules['lift'] >= 1) &
       (rules['confidence'] >= 0.4) ]
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0    (pisang)    (Anggur)            0.417085            0.422111  0.190955
# 1    (Anggur)    (pisang)            0.422111            0.417085  0.190955
# 2     (Jeruk)     (kurma)            0.396985            0.412060  0.165829
# 3     (kurma)     (Jeruk)            0.412060            0.396985  0.165829
#
#    confidence      lift  leverage  conviction
# 0    0.457831  1.084624  0.014899    1.065885
# 1    0.452381  1.084624  0.014899    1.064453
# 2    0.417722  1.013739  0.002247    1.009723
# 3    0.402439  1.013739  0.002247    1.009127

# %%
rules.to_csv('rule.csv', index=False)
